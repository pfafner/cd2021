# %% [markdown]
# # Ciencia de Datos 2021
#
# ### Alan Reyes-Figueroa

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm

from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
from sklearn.cluster import DBSCAN, MeanShift, OPTICS, Birch
from sklearn.metrics import silhouette_samples, silhouette_score

# %% [markdown]
# # Data

# %%
# Generating the sample data
# This particular setting has one distinct cluster and 3 clusters placed close
# together.

X, y = make_blobs(n_samples=500,
                  n_features=2,
                  centers=5,
                  cluster_std=1,
                  center_box=(-10.0, 10.0),
                  shuffle=True,
                  random_state=1)  # For reproducibility

# %%
plt.figure(figsize=(8,8))
plt.scatter(X[:,0], X[:,1], c=y)
plt.show()

# %% [markdown]
# # Mean-Shift

# %%
meanshift = MeanShift(bandwidth=2).fit(X)

# %%
plt.figure(figsize=(8,8))
plt.scatter(X[:,0], X[:,1], c=meanshift.labels_)
plt.show()

# %% [markdown]
# # DBSCAN

# %%
dbscan = DBSCAN(eps=1.5, min_samples=60).fit(X)

# %%
#dbscan.labels_

# %%
plt.figure(figsize=(8,8))
plt.scatter(X[:,0], X[:,1], c=dbscan.labels_)
plt.show()

# %% [markdown]
# # OPTICS

# %%
optics = OPTICS(eps=1.2, min_samples=25).fit(X)

# %%
plt.figure(figsize=(8,8))
plt.scatter(X[:,0], X[:,1], c=optics.labels_)
plt.show()

# %% [markdown]
# # BIRCH

# %%
birch = Birch(n_clusters=None).fit(X)
labels = birch.predict(X)

# %%
plt.figure(figsize=(8,8))
plt.scatter(X[:,0], X[:,1], c=labels)
plt.show()
